# %% [markdown]
# # Resultados preliminares

# %% [markdown]
# **Author** Felipe U.

# %% [markdown]
# Librerias

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns

plt.style.use(['seaborn', "seaborn-dark"][0])
plt.rc('axes', titlesize=14)
plt.rc('legend', fontsize=14)
plt.rc('xtick', labelsize=12)
plt.rc('ytick', labelsize=12)
plt.rcParams.update({'font.size': 16})
plt.rcParams['axes.titlesize'] = 16
plt.rcParams["figure.figsize"] = (10, 6)
plt.rcParams.update({'lines.markeredgewidth': 1})
plt.rcParams.update({'errorbar.capsize': 2})

import pickle
from sklearn.datasets import make_moons, make_circles, make_classification

# %% [markdown]
# # Datasets

# %%
def plot_dataset(X, y, name):
    fig, ax = plt.subplots(1, 1, figsize=(5, 5))
    ax.scatter(X[:, 0], X[:, 1], c=y, cmap="RdYlBu");
    ax.set_title(f"{name} dataset");

# %%
.shape
# Out:
# (100, 2)

# %%
dataset_spiral = make_moons(n_samples=100, noise=0.1, random_state=0)
mu_spiral, std_spiral = dataset_spiral[0].mean(axis=0), dataset_spiral[0].std(axis=0)
dataset_spiral = ((dataset_spiral[0] - mu_spiral) / std_spiral), dataset_spiral[1]
plot_dataset(dataset_spiral[0], dataset_spiral[1], "Espiral")

# %%
dataset_spiral_test = make_moons(n_samples=80, noise=0.1, random_state=1)
dataset_spiral_test = ((dataset_spiral_test[0] - mu_spiral) / std_spiral), dataset_spiral_test[1]
plot_dataset(dataset_spiral_test[0], dataset_spiral_test[1], "Espiral")

# %%
dataset_donut = make_circles(n_samples=100, noise=0.1, factor=0.2, random_state=1)
mu_donut, std_donut = dataset_donut[0].mean(axis=0), dataset_donut[0].std(axis=0)
dataset_donut = ((dataset_donut[0] - mu_donut) / std_donut), dataset_donut[1]
plot_dataset(dataset_donut[0], dataset_donut[1], "Dona")

# %%
dataset_donut_test = make_circles(n_samples=80,noise=0.1, factor=0.2, random_state=2)
dataset_donut_test = ((dataset_donut_test[0] - mu_donut) / std_donut), dataset_donut_test[1]
plot_dataset(dataset_donut_test[0], dataset_donut_test[1], "Dona")
# plt.savefig("dt2.pdf", bbox_inches='tight', )

# %%
X, y = make_classification(
    n_samples=100, n_features=2, n_redundant=0, n_informative=2, random_state=1, n_clusters_per_class=1
)
X += 1.5 * np.random.RandomState(0).uniform(size=X.shape)
linearly_separable = (X, y)
mu_linear, std_linear = linearly_separable[0].mean(axis=0), linearly_separable[0].std(axis=0)
linearly_separable = ((linearly_separable[0] - mu_linear) / std_linear), linearly_separable[1]
plot_dataset(linearly_separable[0], linearly_separable[1], "Linear")

# %%
X, y = make_classification(
    n_samples=100, n_features=2, n_redundant=0, n_informative=2, random_state=1, n_clusters_per_class=1
)
X += 1.5 * np.random.RandomState(1).uniform(size=X.shape)
linearly_separable_test = (X[:80], y[:80])
linearly_separable_test = ((linearly_separable_test[0] - mu_linear) / std_linear), linearly_separable_test[1]
plot_dataset(linearly_separable_test[0], linearly_separable_test[1], "Linear")

# %%
X = 1-2*np.random.RandomState(0).uniform(size=(100, 2))
y = ((X[:, 0] * X[:, 1]) > 0).astype(int)
dataset_uniform = (X, y)
mu_uniform , std_uniform  = dataset_uniform[0].mean(axis=0), dataset_uniform[0].std(axis=0)
dataset_uniform = ((dataset_uniform[0] - mu_uniform ) / std_uniform ), dataset_uniform[1]
plot_dataset(dataset_uniform[0], dataset_uniform[1], "XOR")

# %%
X = 1-2*np.random.RandomState(1).uniform(size=(80, 2))
y = ((X[:, 0] * X[:, 1]) > 0).astype(int)
dataset_uniform_test = (X, y)
dataset_uniform_test = ((dataset_uniform_test[0] - mu_uniform ) / std_uniform ), dataset_uniform_test[1]
plot_dataset(dataset_uniform_test[0], dataset_uniform_test[1], "XOR")

# %% [markdown]
# ## Save Dataset

# %%
pickle.dump(dataset_spiral, open("train_dataset_spiral.pickle", "wb"))
pickle.dump(dataset_donut, open("train_dataset_donut.pickle", "wb"))
pickle.dump(linearly_separable, open("train_dataset_linear.pickle", "wb"))
pickle.dump(dataset_uniform, open("train_dataset_xor.pickle", "wb"))

# %%
pickle.dump(dataset_spiral_test, open("test_dataset_spiral.pickle", "wb"))
pickle.dump(dataset_donut_test, open("test_dataset_donut.pickle", "wb"))
pickle.dump(linearly_separable_test, open("test_dataset_linear.pickle", "wb"))
pickle.dump(dataset_uniform_test, open("test_dataset_xor.pickle", "wb"))
